# %% [markdown]
# # 04 - Pandas - Excel-CSV y otros

# %%
import numpy as np
import pandas as pd
import os
import sys
from IPython.display import display

print("="*15+" PANDAS VERSIÓN")
print(pd.__version__) # imprime versión de pandas (sólo números)
